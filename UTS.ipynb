# %% [markdown]
# <a href="https://colab.research.google.com/github/igedemadepradnyaairlangga/Dataanalitycs/blob/master/UTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Proses Running Sampel Codes dari penelitian yang dilakukan oleh ERFA D. PRASTIANI yang berjudul Data Science with Multiple Algorithms (100% Acc) dengan dataset yang saya download di halaman tersebut juga yaitu Python · E-Shop Clothing Dataset.**

# %% [markdown]
# Guna memenuhi salah satu Tugas untuk UTS dalam matakuliah Data Analitycs

# %% [markdown]
# disini saya akan mempraktekkan cara running sampel codes dari penelitian yang dilakukan oleh ERFA D. PRASTIANI yang berjudul Data Science with Multiple Algorithms (100% Acc) dengan dataset yang saya download di halaman tersebut juga yaitu Python · E-Shop Clothing Dataset.
#
# Di sini kak ERFA D. PRASTIANI mengambil Algoritma Machine Learning yang berbeda dan mencoba menemukan algoritma yang memprediksi secara akurat. yaitu :
# - Logistic Regression
# - Naive Bayes
# - Random Forest Classifier
# - K-Nearest Neighbour
# - Decision Tree
# - Support Vector Machine

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle"
# /content/gdrive/My Drive/Kaggle is the path where kaggle.json is present in the Google Drive

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Kaggle
#Check the present working directory using pwd command

# %%
# !ls
# Out:
#  amazon_prime_titles.csv
# 'e-shop clothing 2008.csv'
# 'e-shop clothing 2008.csv.zip'
#  kaggle.json
# 'Salinan amazon_prime_titles.csv'
#  udemy_output_All_Finance__Accounting_p1_p626.csv

# %%
pip install xgboost

# %%
import numpy as np #Mengolah matrix
import pandas as pd #Read structured data
import matplotlib.pyplot as plt #Data plot visualization
import seaborn as sns

#Machine Learning
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler  #Feature Scaling
from sklearn.model_selection import train_test_split #Data Partition
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,accuracy_score,roc_curve,classification_report
from sklearn.linear_model import LogisticRegression 
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import  RandomForestClassifier
import warnings
warnings.filterwarnings("ignore")
from xgboost import XGBClassifier
from xgboost import plot_importance

#ensembling
from sklearn.ensemble import VotingClassifier

# %% [markdown]
# dataset ini saya download dari kaggle di di penelitian dengan topik Data Science with Multiple Algorithms (100% Acc) Python · E-Shop Clothing Dataset
# yang dibuat oleh ERFA D. PRASTIANI

# %%
df = pd.read_csv(r'e-shop clothing 2008.csv')

# %%
df.shape
# Out:
# (165474, 14)

# %% [markdown]
# df berati data eshop

# %% [markdown]
# DATA DESCRIPTIONS
#
# Independent Variables (x):
#
# year : (2008)
#
# month : from April (4) to August (8)
#
# day : day number of the month
#
# order : sequence of clicks during one session
#
# country :
#
# 1-Australia 2-Austria 3-Belgium 4-British Virgin Islands 5-Cayman Islands 6-Christmas Island 7-Croatia 8-Cyprus 9-Czech Republic 10-Denmark 11-Estonia 12-unidentified 13-Faroe Islands 14-Finland 15-France 16-Germany 17-Greece 18-Hungary 19-Iceland 20-India 21-Ireland 22-Italy 23-Latvia 24-Lithuania 25-Luxembourg 26-Mexico 27-Netherlands 28-Norway 29-Poland 30-Portugal 31-Romania 32-Russia 33-San Marino 34-Slovakia 35-Slovenia 36-Spain 37-Sweden 38-Switzerland 39-Ukraine 40-United Arab Emirates 41-United Kingdom 42-USA 43-biz (.biz) 44-com (.com) 45-int (.int) 46-net (.net) 47-org (*.org)
#
# session ID :
#
# page 1 (main category) :
#
# 1-trousers
#
# 2-skirts
#
# 3-blouses
#
# 4-sale
#
# page 2 (clothing model 1) : contains information about the code for each product (217 products)
#
# colour :
#
# 1-beige
#
# 2-black
#
# 3-blue
#
# 4-brown
#
# 5-burgundy
#
# 6-gray
#
# 7-green
#
# 8-navy blue
#
# 9-of many colors
#
# 10-olive
#
# 11-pink
#
# 12-red
#
# 13-violet
#
# 14-white
#
# location :
# 1-top left
#
# 2-top in the middle
#
# 3-top right
#
# 4-bottom left
#
# 5-bottom in the middle
#
# 6-bottom right
#
# model photography : 1-en face, 2-profile
#
# price : price in US dollars
#
# page : page number within the e-store website (from 1 to 5)
#
# Dependent Variable (y):
#
# target : price 2 (1-yes, 2-no)

# %%
df
# Out:
#         year  month  day  order  country  session ID  page 1 (main category)  \
# 0       2008      4    1      1       29           1                       1
# 1       2008      4    1      2       29           1                       1
# 2       2008      4    1      3       29           1                       2
# 3       2008      4    1      4       29           1                       2
# 4       2008      4    1      5       29           1                       2
# ...      ...    ...  ...    ...      ...         ...                     ...
# 165469  2008      8   13      1       29       24024                       2
# 165470  2008      8   13      1        9       24025                       1
# 165471  2008      8   13      1       34       24026                       1
# 165472  2008      8   13      2       34       24026                       3
# 165473  2008      8   13      3       34       24026                       2
#
# ...

# %%
# filter vriable page
page = df[(df['page']==2)]
page
# Out:
#         year  month  day  order  country  session ID  page 1 (main category)  \
# 9       2008      4    1      1       29           2                       2
# 10      2008      4    1      2       29           2                       2
# 11      2008      4    1      3       29           2                       2
# 12      2008      4    1      4       29           2                       2
# 15      2008      4    1      7       29           2                       2
# ...      ...    ...  ...    ...      ...         ...                     ...
# 165429  2008      8   13     25       29       24018                       4
# 165446  2008      8   13     15       29       24019                       4
# 165450  2008      8   13      2       29       24020                       3
# 165452  2008      8   13      4       29       24020                       2
# 165453  2008      8   13      5       29       24020                       2
#
# ...

# %%
# filter vriable page
page3 = df[(df['page']==3)]
page3
# Out:
#         year  month  day  order  country  session ID  page 1 (main category)  \
# 26      2008      4    1      2       21           4                       1
# 32      2008      4    1      3        9           6                       3
# 40      2008      4    1      6       29           7                       4
# 41      2008      4    1      7       29           7                       4
# 42      2008      4    1      8       29           7                       4
# ...      ...    ...  ...    ...      ...         ...                     ...
# 165380  2008      8   13     56       29       24012                       4
# 165394  2008      8   13      7       29       24014                       4
# 165401  2008      8   13      3       44       24015                       3
# 165404  2008      8   13      2       29       24017                       4
# 165447  2008      8   13     16       29       24019                       4
#
# ...

# %%
harga_no = df[(df['price 2']==2)]
harga_no
# Out:
#         year  month  day  order  country  session ID  page 1 (main category)  \
# 0       2008      4    1      1       29           1                       1
# 1       2008      4    1      2       29           1                       1
# 3       2008      4    1      4       29           1                       2
# 6       2008      4    1      7       29           1                       3
# 13      2008      4    1      5       29           2                       1
# ...      ...    ...  ...    ...      ...         ...                     ...
# 165463  2008      8   13      2       29       24023                       1
# 165464  2008      8   13      3       29       24023                       1
# 165465  2008      8   13      4       29       24023                       1
# 165467  2008      8   13      6       29       24023                       4
# 165471  2008      8   13      1       34       24026                       1
#
# ...

# %%
harga_yes = df[(df['price 2']==1)]
harga_yes
# Out:
#         year  month  day  order  country  session ID  page 1 (main category)  \
# 2       2008      4    1      3       29           1                       2
# 4       2008      4    1      5       29           1                       2
# 5       2008      4    1      6       29           1                       3
# 7       2008      4    1      8       29           1                       4
# 8       2008      4    1      9       29           1                       4
# ...      ...    ...  ...    ...      ...         ...                     ...
# 165468  2008      8   13      7       29       24023                       4
# 165469  2008      8   13      1       29       24024                       2
# 165470  2008      8   13      1        9       24025                       1
# 165472  2008      8   13      2       34       24026                       3
# 165473  2008      8   13      3       34       24026                       2
#
# ...

# %%
numerik= df.select_dtypes(exclude='O')
baju = df.select_dtypes(include='O')

# %%
baju.columns
# Out:
# Index(['page 2 (clothing model)'], dtype='object')

# %%
# encoding for categorical data
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder()
enkode = oe.fit_transform(baju)
enkode
# Out:
# array([[ 4.],
#        [ 7.],
#        [70.],
#        ...,
#        [11.],
#        [87.],
#        [53.]])

# %%
dat_cat = pd.DataFrame(enkode,columns=baju.columns).astype('int')
dat_cat
# Out:
#         page 2 (clothing model)
# 0                             4
# 1                             7
# 2                            70
# 3                            51
# 4                            74
# ...                         ...
# 165469                       44
# 165470                        2
# 165471                       11
# 165472                       87
# 165473                       53
#
# [165474 rows x 1 columns]

# %%
# reconstruct data
df2 = pd.concat([numerik,dat_cat],axis=1)
df2
# Out:
#         year  month  day  order  country  session ID  page 1 (main category)  \
# 0       2008      4    1      1       29           1                       1
# 1       2008      4    1      2       29           1                       1
# 2       2008      4    1      3       29           1                       2
# 3       2008      4    1      4       29           1                       2
# 4       2008      4    1      5       29           1                       2
# ...      ...    ...  ...    ...      ...         ...                     ...
# 165469  2008      8   13      1       29       24024                       2
# 165470  2008      8   13      1        9       24025                       1
# 165471  2008      8   13      1       34       24026                       1
# 165472  2008      8   13      2       34       24026                       3
# 165473  2008      8   13      3       34       24026                       2
#
# ...

# %%
harga_yes2 = df2[(df2['price 2']==1)]
harga_yes2
# Out:
#         year  month  day  order  country  session ID  page 1 (main category)  \
# 2       2008      4    1      3       29           1                       2
# 4       2008      4    1      5       29           1                       2
# 5       2008      4    1      6       29           1                       3
# 7       2008      4    1      8       29           1                       4
# 8       2008      4    1      9       29           1                       4
# ...      ...    ...  ...    ...      ...         ...                     ...
# 165468  2008      8   13      7       29       24023                       4
# 165469  2008      8   13      1       29       24024                       2
# 165470  2008      8   13      1        9       24025                       1
# 165472  2008      8   13      2       34       24026                       3
# 165473  2008      8   13      3       34       24026                       2
#
# ...

# %%
harga_no2 = df2[(df2['price 2']==2)]
harga_no2
# Out:
#         year  month  day  order  country  session ID  page 1 (main category)  \
# 0       2008      4    1      1       29           1                       1
# 1       2008      4    1      2       29           1                       1
# 3       2008      4    1      4       29           1                       2
# 6       2008      4    1      7       29           1                       3
# 13      2008      4    1      5       29           2                       1
# ...      ...    ...  ...    ...      ...         ...                     ...
# 165463  2008      8   13      2       29       24023                       1
# 165464  2008      8   13      3       29       24023                       1
# 165465  2008      8   13      4       29       24023                       1
# 165467  2008      8   13      6       29       24023                       4
# 165471  2008      8   13      1       34       24026                       1
#
# ...

# %%
beige = df2[(df2['colour']==1)]
beige
# Out:
#         year  month  day  order  country  session ID  page 1 (main category)  \
# 0       2008      4    1      1       29           1                       1
# 1       2008      4    1      2       29           1                       1
# 85      2008      4    1     11       21          15                       2
# 100     2008      4    1      1       29          16                       4
# 167     2008      4    1      2       29          30                       2
# ...      ...    ...  ...    ...      ...         ...                     ...
# 165281  2008      8   13      6       29       24007                       1
# 165414  2008      8   13     10       29       24018                       1
# 165430  2008      8   13     26       29       24018                       4
# 165460  2008      8   13      2       29       24022                       1
# 165465  2008      8   13      4       29       24023                       1
#
# ...

# %% [markdown]
# Mengidentifikasi tipe data dan keberadaan nilai yang hilang

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165474 entries, 0 to 165473
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   year                     165474 non-null  int64
#  1   month                    165474 non-null  int64
#  2   day                      165474 non-null  int64
#  3   order                    165474 non-null  int64
#  4   country                  165474 non-null  int64
#  5   session ID               165474 non-null  int64
#  6   page 1 (main category)   165474 non-null  int64
#  7   colour                   165474 non-null  int64
#  8   location                 165474 non-null  int64
#  9   model photography        165474 non-null  int64
#  10  price                    165474 non-null  int64
#  11  price 2                  165474 non-null  int64
#  12  page                     165474 non-null  int64
#  13  page 2 (clothing model)  165474 non-null  int64
# ...

# %%
cols= ["#C2C4E2","#EED4E5"]
plt.figure(figsize=(10,10))
sns.countplot(x= df2['price 2'], palette = 'Blues')

plt.show()

# %%
cols= ["#C2C4E2","#EED4E5"]
plt.figure(figsize=(10,10))
sns.barplot(x= df2['page 1 (main category)'], y= df2['price'],palette = 'Blues')
plt.xlabel('Kategori Pakaian')
plt.ylabel('Harga (Dalam Dollar)')
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.barplot(x=df2['country'],y=df2['colour'])
plt.show()

# %% [markdown]
# Plot warna pakaian beige paling banyak di negara mana?

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=beige['country'])
plt.show()

# %% [markdown]
# Negara Polandia adalah negara yang paling banyak membeli pakaian berwarna beige

# %%
corr = df2.corr(method = 'pearson')

# %%
colormap = plt.cm.PuBu 
plt.figure(figsize=(15,5)) 
plt.title("Person Correlation of Features", y = 1, size = 20) 
sns.heatmap(corr.astype(float).corr(), linecolor = "white", cmap = colormap, annot = True)

# %% [markdown]
# Dari tabel korelasi dapat dilihat bahwa age mempunyai hubungan linear positif yang sangat kuat dengan target jika dibandingkan yang lain. Nilai korelasi variabel lain hampir mendekati nol yang menandakan bahwa variable2 tersebut kurang berpengaruh terhadap nilai target.

# %% [markdown]
# **DATA PREPARATION**
# Missing Value Checking

# %%
df2.isnull().sum()
# Out:
# year                       0
# month                      0
# day                        0
# order                      0
# country                    0
# session ID                 0
# page 1 (main category)     0
# colour                     0
# location                   0
# model photography          0
# price                      0
# price 2                    0
# page                       0
# page 2 (clothing model)    0
# dtype: int64

# %% [markdown]
# Langkah selanjutnya adalah memperoleh pengetahuan tentang statistik ringkasan data dasar menggunakan metode .describe(), yang menghitung nilai count, mean, standar deviasi, minimum, maksimum dan persentil (25, 50 dan 75). Ini membantu kita mendeteksi anomali apa pun dalam kumpulan data kita. Seperti variabel dengan varians tinggi atau data yang sangat miring.

# %%
df.describe()
# Out:
#            year          month            day          order        country  \
# count  165474.0  165474.000000  165474.000000  165474.000000  165474.000000
# mean     2008.0       5.585887      14.524554       9.817476      26.952621
# std         0.0       1.328160       8.830374      13.478411       7.150691
# min      2008.0       4.000000       1.000000       1.000000       1.000000
# 25%      2008.0       4.000000       7.000000       2.000000      29.000000
# 50%      2008.0       5.000000      14.000000       6.000000      29.000000
# 75%      2008.0       7.000000      22.000000      12.000000      29.000000
# max      2008.0       8.000000      31.000000     195.000000      47.000000
#
#           session ID  page 1 (main category)         colour       location  \
# count  165474.000000           165474.000000  165474.000000  165474.000000
# mean    12058.417056                2.400842       6.227655       3.258198
# ...

# %% [markdown]
# Outlier Finding

# %%
sns.boxplot(df2["day"])

# %%
sns.boxplot(df2["session ID"])

# %%
sns.boxplot(df2["page 1 (main category)"])

# %%
sns.boxplot(df2["page 2 (clothing model)"])

# %%
sns.boxplot(df2["colour"])

# %%
sns.boxplot(df2["price"])

# %%
sns.boxplot(df2["page"])

# %% [markdown]
# Outlier Fixing (price, page)
#
# -> price

# %%
#Data 'price' diisi dengan median
fill=df2["price"].median()
df2["price"]=df2["price"].fillna(fill)

# %%
#lihat outlier observasi pada variabel 'price'
Q1 =df2["price"].quantile(0.25)
Q3 =df2["price"].quantile(0.75)    
IQR=Q3-Q1
lower_range = Q1 -(1.5 * IQR)
upper_range = Q3 +(1.5 * IQR)
df2.loc[(df2["price"]>upper_range),:]
# Out:
#         year  month  day  order  country  session ID  page 1 (main category)  \
# 115     2008      4    1      7        9          18                       1
# 237     2008      4    1      3        9          40                       1
# 321     2008      4    1     31        9          49                       1
# 380     2008      4    1      5       29          58                       1
# 426     2008      4    1      4       24          67                       1
# ...      ...    ...  ...    ...      ...         ...                     ...
# 165133  2008      8   12      4       29       23993                       1
# 165134  2008      8   12      5       29       23993                       1
# 165214  2008      8   12     38       34       23999                       1
# 165290  2008      8   13      1       29       24009                       1
# 165411  2008      8   13      7       29       24018                       1
#
# ...

# %%
#Ganti outlier observations dengan upper bound dan lower bound
df2.loc[(df2["price"]>upper_range),"price"]=upper_range

# %%
sns.boxplot(df2["price"])

# %% [markdown]
# -> page

# %%
#Data 'page' diisi dengan median
fill=df2["page"].median()
df2["page"]=df2["page"].fillna(fill)

# %%
#lihat outlier observasi pada variabel 'page'
Q1 =df2["page"].quantile(0.25)
Q3 =df2["page"].quantile(0.75)    
IQR=Q3-Q1
lower_range = Q1 -(1.5 * IQR)
upper_range = Q3 +(1.5 * IQR)
df2.loc[(df2["page"]>upper_range),:]
# Out:
#         year  month  day  order  country  session ID  page 1 (main category)  \
# 5       2008      4    1      6       29           1                       3
# 6       2008      4    1      7       29           1                       3
# 7       2008      4    1      8       29           1                       4
# 8       2008      4    1      9       29           1                       4
# 24      2008      4    1      6       21           3                       4
# ...      ...    ...  ...    ...      ...         ...                     ...
# 165397  2008      8   13     10       29       24014                       4
# 165398  2008      8   13     11       29       24014                       3
# 165430  2008      8   13     26       29       24018                       4
# 165431  2008      8   13     27       29       24018                       4
# 165448  2008      8   13     17       29       24019                       4
#
# ...

# %%
#Ganti outlier observations dengan upper bound dan lower bound
df2.loc[(df2["page"]>upper_range),"page"]=upper_range

# %%
sns.boxplot(df2["page"])

# %% [markdown]
# Finding Duplicate Data

# %%
df2.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 165469    False
# 165470    False
# 165471    False
# 165472    False
# 165473    False
# Length: 165474, dtype: bool

# %% [markdown]
# Sebelum menerapkan algoritma kita harus memeriksa apakah data dibagi rata atau tidak, karena jika data tidak dibagi rata akan menyebabkan masalah ketidakseimbangan data

# %% [markdown]
# Train and Test Split
#
# Seluruh kumpulan data umumnya dibagi menjadi 80% train dan 20% kumpulan data uji (aturan umum). Data latih 80% digunakan untuk pelatihan model, sedangkan 20% sisanya digunakan untuk memeriksa bagaimana model digeneralisasikan pada kumpulan data yang tidak terlihat.

# %%
y = df2["price 2"]
X = df2.drop('price 2',axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.20, random_state = 0)

# %% [markdown]
# Normalization / Feature Scaling
#
# Membuat tiap fitur memiliki nilai rata-rata 0 dan variansi 1.

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

#https://www.megabagus.id/feature-scaling/

# %% [markdown]
# **MODEL FITTING**
# Di sini saya mengambil Algoritma Machine Learning yang berbeda dan mencoba menemukan algoritma yang memprediksi secara akurat.
#
# - Logistic Regression
# - Naive Bayes
# - Random Forest Classifier
# - K-Nearest Neighbour
# - Decision Tree
# - Support Vector Machine

# %%
m1 = 'Logistic Regression'
lr = LogisticRegression()
model = lr.fit(X_train, y_train)
lr_predict = lr.predict(X_test)
lr_conf_matrix = confusion_matrix(y_test, lr_predict)
lr_acc_score = accuracy_score(y_test, lr_predict)
print("confussion matrix")
print(lr_conf_matrix)
print("\n")
print("Accuracy of Logistic Regression:",lr_acc_score*100,'\n')
print(classification_report(y_test,lr_predict))
# Out:
# confussion matrix
# [[67604   232]
#  [    0 64544]]
#
#
# Accuracy of Logistic Regression: 99.82474694062547
#
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     67836
#            2       1.00      1.00      1.00     64544
#
#     accuracy                           1.00    132380
#    macro avg       1.00      1.00      1.00    132380
# weighted avg       1.00      1.00      1.00    132380

# %%
m2 = 'Naive Bayes'
nb = GaussianNB()
nb.fit(X_train,y_train)
nbpred = nb.predict(X_test)
nb_conf_matrix = confusion_matrix(y_test, nbpred)
nb_acc_score = accuracy_score(y_test, nbpred)
print("confussion matrix")
print(nb_conf_matrix)
print("\n")
print("Accuracy of Naive Bayes model:",nb_acc_score*100,'\n')
print(classification_report(y_test,nbpred))
# Out:
# confussion matrix
# [[58561  9275]
#  [ 2570 61974]]
#
#
# Accuracy of Naive Bayes model: 91.05227375736517
#
#               precision    recall  f1-score   support
#
#            1       0.96      0.86      0.91     67836
#            2       0.87      0.96      0.91     64544
#
#     accuracy                           0.91    132380
#    macro avg       0.91      0.91      0.91    132380
# weighted avg       0.91      0.91      0.91    132380

# %%
m3 = 'Random Forest Classfier'
rf = RandomForestClassifier(n_estimators=20, random_state=12,max_depth=5)
rf.fit(X_train,y_train)
rf_predicted = rf.predict(X_test)
rf_conf_matrix = confusion_matrix(y_test, rf_predicted)
rf_acc_score = accuracy_score(y_test, rf_predicted)
print("confussion matrix")
print(rf_conf_matrix)
print("\n")
print("Accuracy of Random Forest:",rf_acc_score*100,'\n')
print(classification_report(y_test,rf_predicted))
# Out:
# confussion matrix
# [[67836     0]
#  [  356 64188]]
#
#
# Accuracy of Random Forest: 99.73107720199425
#
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00     67836
#            2       1.00      0.99      1.00     64544
#
#     accuracy                           1.00    132380
#    macro avg       1.00      1.00      1.00    132380
# weighted avg       1.00      1.00      1.00    132380

# %%
m4 = 'K-NeighborsClassifier'
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train, y_train)
knn_predicted = knn.predict(X_test)
knn_conf_matrix = confusion_matrix(y_test, knn_predicted)
knn_acc_score = accuracy_score(y_test, knn_predicted)
print("confussion matrix")
print(knn_conf_matrix)
print("\n")
print("Accuracy of K-NeighborsClassifier:",knn_acc_score*100,'\n')
print(classification_report(y_test,knn_predicted))
# Out:
# confussion matrix
# [[67340   496]
#  [  938 63606]]
#
#
# Accuracy of K-NeighborsClassifier: 98.91675479679711
#
#               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99     67836
#            2       0.99      0.99      0.99     64544
#
#     accuracy                           0.99    132380
#    macro avg       0.99      0.99      0.99    132380
# weighted avg       0.99      0.99      0.99    132380

# %%
m5 = 'DecisionTreeClassifier'
dt = DecisionTreeClassifier(criterion = 'entropy',random_state=0,max_depth = 6)
dt.fit(X_train, y_train)
dt_predicted = dt.predict(X_test)
dt_conf_matrix = confusion_matrix(y_test, dt_predicted)
dt_acc_score = accuracy_score(y_test, dt_predicted)
print("confussion matrix")
print(dt_conf_matrix)
print("\n")
print("Accuracy of DecisionTreeClassifier:",dt_acc_score*100,'\n')
print(classification_report(y_test,dt_predicted))
# Out:
# confussion matrix
# [[67836     0]
#  [    0 64544]]
#
#
# Accuracy of DecisionTreeClassifier: 100.0
#
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     67836
#            2       1.00      1.00      1.00     64544
#
#     accuracy                           1.00    132380
#    macro avg       1.00      1.00      1.00    132380
# weighted avg       1.00      1.00      1.00    132380

# %%
m6 = 'Support Vector Classifier'
svc =  SVC(kernel='rbf', C=2)
svc.fit(X_train, y_train)
svc_predicted = svc.predict(X_test)
svc_conf_matrix = confusion_matrix(y_test, svc_predicted)
svc_acc_score = accuracy_score(y_test, svc_predicted)
print("confussion matrix")
print(svc_conf_matrix)
print("\n")
print("Accuracy of Support Vector Classifier:",svc_acc_score*100,'\n')
print(classification_report(y_test,svc_predicted))
# Out:
# confussion matrix
# [[67812    24]
#  [   16 64528]]
#
#
# Accuracy of Support Vector Classifier: 99.96978395528025
#
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     67836
#            2       1.00      1.00      1.00     64544
#
#     accuracy                           1.00    132380
#    macro avg       1.00      1.00      1.00    132380
# weighted avg       1.00      1.00      1.00    132380

# %%
model = XGBClassifier()
masuk = model.fit(X,y)
print(model.feature_importances_)
# Out:
# [0.         0.         0.         0.         0.         0.
#  0.22062385 0.05402506 0.01313162 0.         0.6005976  0.00326319
#  0.1083587 ]

# %%
plot_importance(model)
plt.show()

# %% [markdown]
# **MODEL EVALUATION**

# %%
model_ev = pd.DataFrame({'Model': ['Logistic Regression','Naive Bayes','Random Forest',
                    'K-Nearest Neighbour','Decision Tree','Support Vector Machine'], 'Accuracy': [lr_acc_score*100,
                    nb_acc_score*100,rf_acc_score*100,knn_acc_score*100,dt_acc_score*100,svc_acc_score*100]})
model_ev
# Out:
#                     Model    Accuracy
# 0     Logistic Regression   99.824747
# 1             Naive Bayes   91.052274
# 2           Random Forest   99.731077
# 3     K-Nearest Neighbour   98.916755
# 4           Decision Tree  100.000000
# 5  Support Vector Machine   99.969784

# %%
colors = ['red','green','blue','purple','yellow','orange',]
plt.figure(figsize=(12,5))
plt.title("barplot Represent Accuracy of different models")
plt.xlabel("Accuracy % \n")
plt.ylabel("Algorithms \n")
plt.bar(model_ev['Model'],model_ev['Accuracy'],color = colors)
plt.show()

# %% [markdown]
# Max Voting

# %% [markdown]
# **ENSEMBLING**
# In order to increase the accuracy of the model we use ensembling. Here I use Max Voting technique (BASIC).
#
# Metode max voting umumnya digunakan untuk masalah klasifikasi. Dalam teknik ini, beberapa model digunakan untuk membuat prediksi untuk setiap titik data. Prediksi oleh masing-masing model dianggap sebagai 'suara'. Prediksi yang didapatkan dari sebagian besar model digunakan sebagai prediksi akhir.

# %%
m1 = LogisticRegression()
m2 = GaussianNB()
m3 = RandomForestClassifier()
m4 = KNeighborsClassifier()
m5 = DecisionTreeClassifier()
m6 = SVC()

model = VotingClassifier(estimators
    =[('lr', m1), ('nb', m2), ('rf', m3),
      ('knn', m4), ('dt', m5), ('svc', m6)], voting='hard')
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# **CONCLUSION**

# %% [markdown]
# - Serangkaian model yang beragam cenderung membuat keputusan yang lebih baik dibandingkan dengan dengan model tunggal.
# - Data yang paling besar pengaruhnya terhadap harga rata-rata diantaranya adalah price, page 1(main category), page 2(clothing model), location, colour, page.

# %% [markdown]
# **PENUTUP**

# %% [markdown]
# Sekian dari proses Running sempel codes dari saya yang mengambil materi penelitian dari kak ERFA D. PRASTIAN. semoga dapat dimengerti dan saya ucapkan terimakasih kepada kak ERFA D. PRASTIAN. sudah memberikan dataset dan codes untuk menjalankan penelitiannya. saya juga minta maaf tidak ijin dahulu sebelum meng-upload proses Running sempel codes ini ke akun github saya pribadi dikarenakan tidak memiliki dan tidak bisa menghubungi pihak terkait
#
# Terimakasih
